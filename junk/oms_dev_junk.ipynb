
  'timestamp': Timestamp('2023-07-19 00:00:00'),
  'orderSide': 'BUY',
  'entryPrice': 187.90253479135262,
  'slPrice': 187.52672972176993,
  'targetPrice': 188.27833986093532,
  'orderType': 'MARKET',
  'timeInForce': 'DAY',
  'orderQuantity': 20.0},
 {'symbol': 'INTC',
  'timestamp': Timestamp('2023-07-19 00:00:00'),
  'orderSide': 'BUY',
  'entryPrice': 154.3252555271092,
  'slPrice': 154.01660501605497,
  'targetPrice': 154.63390603816342,
  'orderType': 'MARKET',
  'timeInForce': 'DAY',
  'orderQuantity': 1.0},
 {'symbol': 'PG',
  'timestamp': Timestamp('2023-07-19 00:00:00'),
  'orderSide': 'BUY',
  'entryPrice': 177.19804766115195,
  'slPrice': 176.84365156582965,
  'targetPrice': 177.55244375647425,
  'orderType': 'MARKET',
  'timeInForce': 'DAY',
  'orderQuantity': 21.0},
 {'symbol': 'NVDA',
  'timestamp': Timestamp('2023-07-19 00:00:00'),
  'orderSide': 'BUY',
  'entryPrice': 187.7101330926931,
  'slPrice': 187.3347128265077,
  'targetPrice': 188.08555335887849,
  'orderType': 'MARKET',
  'timeInForce': 'DAY',
  'orderQuantity': 3.0},
 {'symbol': 'XOM',
  'timestamp': Timestamp('2023-07-19 00:00:00'),
  'orderSide': 'SELL',
  'entryPrice': 101.32675122322887,
  'slPrice': 101.52940472567532,
  'targetPrice': 101.12409772078242,
  'orderType': 'MARKET',
  'timeInForce': 'DAY',
  'orderQuantity': 17.0},
 {'symbol': 'FB',
  'timestamp': Timestamp('2023-07-19 00:00:00'),
  'orderSide': 'SELL',
  'entryPrice': 120.48480353543567,
  'slPrice': 120.72577314250654,
  'targetPrice': 120.24383392836481,
  'orderType': 'MARKET',
  'timeInForce': 'DAY',
  'orderQuantity': 19.0},
 {'symbol': 'MSFT',
  'timestamp': Timestamp('2023-07-19 00:00:00'),
  'orderSide': 'SELL',
  'entryPrice': 124.40910425648656,
  'slPrice': 124.65792246499953,
  'targetPrice': 124.16028604797359,
  'orderType': 'MARKET',
  'timeInForce': 'DAY',
  'orderQuantity': 19.0},
 {'symbol': 'HD',
  'timestamp': Timestamp('2023-07-19 00:00:00'),
  'orderSide': 'SELL',
  'entryPrice': 133.91860299251468,
  'slPrice': 134.1864401984997,
  'targetPrice': 133.65076578652966,
  'orderType': 'MARKET',
  'timeInForce': 'DAY',
  'orderQuantity': 19.0},
 {'symbol': 'JPM',
  'timestamp': Timestamp('2023-07-19 00:00:00'),
  'orderSide': 'SELL',
  'entryPrice': 133.70959995181218,
  'slPrice': 133.9770191517158,
  'targetPrice': 133.44218075190855,
  'orderType': 'MARKET',
  'timeInForce': 'DAY',
  'orderQuantity': 20.0},
 {'symbol': 'DIS',
  'timestamp': Timestamp('2023-07-19 00:00:00'),
  'orderSide': 'SELL',
  'entryPrice': 149.05802123807155,
  'slPrice': 149.3561372805477,
  'targetPrice': 148.7599051955954,
  'orderType': 'MARKET',
  'timeInForce': 'DAY',
  'orderQuantity': 20.0},
 {'symbol': 'AMZN',
  'timestamp': Timestamp('2023-07-19 00:00:00'),
  'orderSide': 'SELL',
  'entryPrice': 110.07858687426095,
  'slPrice': 110.29874404800947,
  'targetPrice': 109.85842970051243,
  'orderType': 'MARKET',
  'timeInForce': 'DAY',
  'orderQuantity': 20.0},
 {'symbol': 'NFLX',
  'timestamp': Timestamp('2023-07-19 00:00:00'),
  'orderSide': 'SELL',
  'entryPrice': 154.64842303201655,
  'slPrice': 154.95771987808058,
  'targetPrice': 154.33912618595252,
  'orderType': 'MARKET',
  'timeInForce': 'DAY',
  'orderQuantity': 2.0},
 {'symbol': 'JNJ',
  'timestamp': Timestamp('2023-07-19 00:00:00'),
  'orderSide': 'SELL',
  'entryPrice': 171.53675705782933,
  'slPrice': 171.87983057194498,
  'targetPrice': 171.1936835437137,
  'orderType': 'MARKET',
  'timeInForce': 'DAY',
  'orderQuantity': 23.0}]

# %%
# Convert the orders to a pandas dataframe
orders_df = pd.DataFrame(orders)

# save orders to a json file in folder: '/Users/vandanchopra/Vandan_Personal_Folder/CODE_STUFF/Projects/mathematricks/junk'
orders_df.to_json('/Users/vandanchopra/Vandan_Personal_Folder/CODE_STUFF/Projects/mathematricks/junk/orders_template.json', orient='records')

# %%
# load the orders from the json file
orders_df = pd.read_json('/Users/vandanchopra/Vandan_Personal_Folder/CODE_STUFF/Projects/mathematricks/junk/orders_template.json', orient='records')
# convert orders_df to list
orders = orders_df.to_dict(orient='records')

# %%
# Create a dictionary to store unique values for all keys in the orders
unique_values = {}
for order in orders:
    for key, value in order.items():
        if key not in unique_values:
            unique_values[key] = set()
        unique_values[key].add(value)

# %%
# drop the following keys from the unique_values dictionary
keys_to_drop = ['timestamp', 'orderQuantity', 'entryPrice', 'targetPrice']
for key in keys_to_drop:
    unique_values.pop(key)

# %%
unique_values
# Out:
# {'symbol': {'AAPL',
#   'AMD',
#   'AMZN',
#   'CRM',
#   'DIS',
#   'FB',
#   'GOOGL',
#   'HD',
#   'INTC',
#   'JNJ',
#   'JPM',
#   'MSFT',
#   'NFLX',
#   'NKE',
#   'NVDA',
#   'PG',
#   'TSLA',
#   'UNH',
#   'V',
#   'XOM'},
#  'orderSide': {'BUY', 'SELL'},
#  'slPrice': {99.7835785297,
#   101.5294047257,
#   102.1621452527,
#   103.8348145954,
#   107.2406539201,
#   108.4924500208,
#   110.298744048,
#   111.8879581462,
#   120.7257731425,
#   124.657922465,
#   128.6569775185,
#   131.5824898047,
#   133.9770191517,
#   134.1864401985,
#   140.6973955714,
#   141.0688634607,
#   143.7421654393,
#   149.3561372805,
#   151.1366551275,
#   154.0166050161,
#   154.9577198781,
#   155.9436726888,
#   157.5158132046,
#   159.334505189,
#   160.8621157186,
#   161.8945219216,
#   167.856557725,
#   171.8798305719,
#   172.3735409656,
#   176.8436515658,
#   179.1184289719,
#   180.2131884168,
#   187.0078001978,
#   187.3347128265,
#   187.5267297218,
#   189.4773818348,
# ...

# %%
from ib_insync import IB, util, Stock, Order

# %%
symbol = 'INTC'
currency = 'USD'
primaryExchange = 'NASDAQ'

contract = Stock(symbol=symbol, exchange='SMART', currency=currency, primaryExchange=primaryExchange)
direction = 'SELL'
quantity = 10
stop_price = 151.1366551275291

# Create a stop-loss order
stop_loss_order = Order(
    action=direction,           # 'SELL' to close or reduce a long position
    totalQuantity=quantity,     # Number of shares
    orderType='STP',            # Stop order
    auxPrice=stop_price,        # Stop price
    tif='GTC'                   # Good-till-canceled
)

# %%
# Out:
# Order(action='SELL', totalQuantity=10, orderType='STP', auxPrice=151.1366551275291, tif='GTC')

# %%
{'symbol': 'INTC',
 'timestamp': Timestamp('2023-01-01 01:39:00'),
 'orderSide': 'SELL',
 'entryPrice': 151.4395341959,
 'slPrice': 151.1366551275,
 'targetPrice': 151.7424132643,
 'orderType': 'MARKET',
 'timeInForce': 'DAY',
 'orderQuantity': 10}

# %%
orders[0]
# Out:
# {'symbol': 'INTC',
#  'timestamp': Timestamp('2023-01-01 01:39:00'),
#  'orderSide': 'BUY',
#  'entryPrice': 151.4395341959,
#  'slPrice': 151.1366551275,
#  'targetPrice': 151.7424132643,
#  'orderType': 'MARKET',
#  'timeInForce': 'DAY',
#  'orderQuantity': 10}

# %%
orders = [[
{'symbol': 'INTC',
 'timestamp': Timestamp('2023-01-01 01:39:00'),
 'orderSide': 'BUY',
 'entryPrice': 151.4395341959,
 'orderType': 'MARKET',
 'timeInForce': 'DAY',
 'orderQuantity': 10}, 

{'symbol': 'INTC',
 'timestamp': Timestamp('2023-01-01 01:39:00'),
 'orderSide': 'SELL',
 'exitPrice': 149.4395341959,
 'orderType': 'STOPLOSS-MARKET',
 'timeInForce': 'DAY',
 'orderQuantity': 10}]]
